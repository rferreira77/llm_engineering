# %% [markdown]
# # RAG Day 4
#
# ## Evaluation!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Keep in mind how you would evaluate RAG for your business</h2>
#             <span style="color:#181;">This is such an important part of building an accurate and reliable RAG pipeline. And it's applicable to many aspects of solving business problems with LLMs. People are often focused on RAG architecture and RAG frameworks for their business. But even more important: evaluations!</span>
#         </td>
#     </tr>
# </table>

# %%
from evaluation import test

# %%
tests = test.load_tests()

# %%
len(tests)
# Out:
# 150

# %%
example = tests[0]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# Who won the prestigious IIOTY award in 2023?
# direct_fact
# Maxine Thompson won the prestigious Insurellm Innovator of the Year (IIOTY) award in 2023.
# ['Maxine', 'Thompson', 'IIOTY']

# %%
from collections import Counter
count = Counter([t.category for t in tests])
count
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer

# %%
evaluate_retrieval(example)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 evaluate_retrieval(example)
#
# File c:\Users\ricar\Projects\llm_engineering\week5\evaluation\eval.py:92, in evaluate_retrieval(test, k)
#      81 """
#      82 Evaluate retrieval performance for a test question.
#      83
#    (...)     89     RetrievalEval object with MRR, nDCG, and keyword coverage metrics
#      90 """
#      91 # Retrieve documents using shared answer module
# ---> 92 retrieved_docs = fetch_context(test.question)
#      94 # Calculate MRR (average across all keywords)
#      95 mrr_scores = [calculate_mrr(keyword, retrieved_docs) for keyword in test.keywords]
#
# File c:\Users\ricar\Projects\llm_engineering\week5\implementation\answer.py:38, in fetch_context(question)
#      34 def fetch_context(question: str) -> list[Document]:
#      35     """
#      36     Retrieve relevant context documents for a question.
#      37     """
# ---> 38     return retriever.invoke(question, k=RETRIEVAL_K)
#
# File c:\Users\ricar\Projects\llm_engineering\.venv\Lib\site-packages\langchain_core\retrievers.py:216, in BaseRetriever.invoke(self, input, config, **kwargs)
#     214 kwargs_ = kwargs if self._expects_other_args else {}
#     215 if self._new_arg_supported:
# --> 216     result = self._get_relevant_documents(
#     217         input, run_manager=run_manager, **kwargs_
#     218     )
#     219 else:
#     220     result = self._get_relevant_documents(input, **kwargs_)
#
# File c:\Users\ricar\Projects\llm_engineering\.venv\Lib\site-packages\langchain_core\vectorstores\base.py:1033, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1031 kwargs_ = self.search_kwargs | kwargs
#    1032 if self.search_type == "similarity":
# -> 1033     docs = self.vectorstore.similarity_search(query, **kwargs_)
#    1034 elif self.search_type == "similarity_score_threshold":
#    1035     docs_and_similarities = (
#    1036         self.vectorstore.similarity_search_with_relevance_scores(
#    1037             query, **kwargs_
#    1038         )
#    1039     )
#
# File c:\Users\ricar\Projects\llm_engineering\.venv\Lib\site-packages\langchain_chroma\vectorstores.py:695, in Chroma.similarity_search(self, query, k, filter, **kwargs)
#     677 def similarity_search(
#     678     self,
#     679     query: str,
#    (...)    682     **kwargs: Any,
#     683 ) -> list[Document]:
#     684     """Run similarity search with Chroma.
#     685
#     686     Args:
#    (...)    693         List of documents most similar to the query text.
#     694     """
# --> 695     docs_and_scores = self.similarity_search_with_score(
#     696         query,
#     697         k,
#     698         filter=filter,
#     699         **kwargs,
#     700     )
#     701     return [doc for doc, _ in docs_and_scores]
#
# File c:\Users\ricar\Projects\llm_engineering\.venv\Lib\site-packages\langchain_chroma\vectorstores.py:796, in Chroma.similarity_search_with_score(self, query, k, filter, where_document, **kwargs)
#     794 else:
#     795     query_embedding = self._embedding_function.embed_query(query)
# --> 796     results = self.__query_collection(
#     797         query_embeddings=[query_embedding],
#     798         n_results=k,
#     799         where=filter,
#     800         where_document=where_document,
#     801         **kwargs,
#     802     )
#     804 return _results_to_docs_and_scores(results)
#
# File c:\Users\ricar\Projects\llm_engineering\.venv\Lib\site-packages\langchain_core\utils\utils.py:52, in xor_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      46     msg = (
#      47         "Exactly one argument in each of the following"
#      48         " groups must be defined:"
#      49         f" {', '.join(invalid_group_names)}"
#      50     )
#      51     raise ValueError(msg)
# ---> 52 return func(*args, **kwargs)
#
# File c:\Users\ricar\Projects\llm_engineering\.venv\Lib\site-packages\langchain_chroma\vectorstores.py:470, in Chroma.__query_collection(self, query_texts, query_embeddings, n_results, where, where_document, **kwargs)
#     442 @xor_args(("query_texts", "query_embeddings"))
#     443 def __query_collection(
#     444     self,
#    (...)    450     **kwargs: Any,
#     451 ) -> list[Document] | chromadb.QueryResult:
#     452     """Query the chroma collection.
#     453
#     454     Args:
#    (...)    468     See more: https://docs.trychroma.com/reference/py-collection#query
#     469     """
# --> 470     return self._collection.query(
#     471         query_texts=query_texts,
#     472         query_embeddings=query_embeddings,  # type: ignore[arg-type]
#     473         n_results=n_results,
#     474         where=where,  # type: ignore[arg-type]
#     475         where_document=where_document,  # type: ignore[arg-type]
#     476         **kwargs,
#     477     )
#
# File c:\Users\ricar\Projects\llm_engineering\.venv\Lib\site-packages\chromadb\api\models\Collection.py:227, in Collection.query(self, query_embeddings, query_texts, query_images, query_uris, ids, n_results, where, where_document, include)
#     191 """Get the n_results nearest neighbor embeddings for provided query_embeddings or query_texts.
#     192
#     193 Args:
#    (...)    212
#     213 """
#     215 query_request = self._validate_and_prepare_query_request(
#     216     query_embeddings=query_embeddings,
#     217     query_texts=query_texts,
#    (...)    224     include=include,
#     225 )
# --> 227 query_results = self._client._query(
#     228     collection_id=self.id,
#     229     ids=query_request["ids"],
#     230     query_embeddings=query_request["embeddings"],
#     231     n_results=query_request["n_results"],
#     232     where=query_request["where"],
#     233     where_document=query_request["where_document"],
#     234     include=query_request["include"],
#     235     tenant=self.tenant,
#     236     database=self.database,
#     237 )
#     239 return self._transform_query_response(
#     240     response=query_results, include=query_request["include"]
#     241 )
#
# File c:\Users\ricar\Projects\llm_engineering\.venv\Lib\site-packages\chromadb\api\rust.py:539, in RustBindingsAPI._query(self, collection_id, query_embeddings, ids, n_results, where, where_document, include, tenant, database)
#     523 filtered_ids_amount = len(ids) if ids else 0
#     524 self.product_telemetry_client.capture(
#     525     CollectionQueryEvent(
#     526         collection_uuid=str(collection_id),
#    (...)    536     )
#     537 )
# --> 539 rust_response = self.bindings.query(
#     540     str(collection_id),
#     541     ids,
#     542     query_embeddings,
#     543     n_results,
#     544     json.dumps(where) if where else None,
#     545     json.dumps(where_document) if where_document else None,
#     546     include,
#     547     tenant,
#     548     database,
#     549 )
#     551 return QueryResult(
#     552     ids=rust_response.ids,
#     553     embeddings=rust_response.embeddings,
#    (...)    559     distances=rust_response.distances,
#     560 )
#
# InvalidArgumentError: Collection expecting embedding with dimension of 384, got 3072

# %%
eval, answer, chunks = evaluate_answer(example)

# %%
eval
# Out:
# AnswerEval(feedback="The answer correctly identifies Maxine as the winner and mentions the IIOTY award in 2023, but it omits Thompson's full name, which is present in the reference. This affects completeness. The relevance is high, as it directly addresses the question about the award winner.", accuracy=5.0, completeness=4.0, relevance=5.0)

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)
# Out:
# The answer correctly identifies Maxine as the winner and mentions the IIOTY award in 2023, but it omits Thompson's full name, which is present in the reference. This affects completeness. The relevance is high, as it directly addresses the question about the award winner.
# 5.0
# 4.0
# 5.0
